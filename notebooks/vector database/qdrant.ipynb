# %%
from qdrant_client import QdrantClient
from qdrant_client.models import PointStruct, Distance, Filter, FieldCondition, MatchValue, VectorParams
from sentence_transformers import SentenceTransformer
# Out:
# WARNING:tensorflow:From c:\Users\Mario\AppData\Local\Programs\Python\Python313\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
model = SentenceTransformer('all-MiniLM-L6-v2')
# client = QdrantClient(host='localhost', port=6333)

# %%
client = QdrantClient(
    url="https://3b3c6ad1-200f-47e0-96bc-32b0562fc8d2.us-west-2-0.aws.cloud.qdrant.io",
    api_key="eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhY2Nlc3MiOiJtIiwic3ViamVjdCI6ImFwaS1rZXk6ZjQ5NTlhMTktODI2Yy00MjZlLWIwNWEtN2RmYWEwNmE2N2RmIn0.b_nw6sn-OexkwiunKZhOhTOu60Xybp0kyZ6wQXLA-qU",
    cloud_inference=True
)

# %%
documents = [
    {
        "id": 1,
        "text": "Qdrant is a vector database for similarity search.",
        "source": "note_1"
    },
    {
        "id": 2,
        "text": "CLIP can embed images and text into the same vector space.",
        "source": "note_2"
    },
    {
        "id": 3,
        "text": "FastAPI is often used to build backend APIs in Python.",
        "source": "note_3"
    }
]

texts = [doc["text"] for doc in documents]
vectors = model.encode(texts).tolist()

for text, vector in zip(texts, vectors):
    print(f"Text: {text}\nVector: {vector}\n")
    print("-" * 80)
# Out:
# Text: Qdrant is a vector database for similarity search.
# ...

# %%
collection_name = 'text_docs'

client.create_collection(
    collection_name=collection_name,
    vectors_config=VectorParams(size=len(vectors[0]), distance=Distance.COSINE)
)
