# %%
import sys
!"{sys.executable}" -m pip install -U qdrant-client

import qdrant_client
print("qdrant_client version:", getattr(qdrant_client, "__version__", "(unknown)"))
print("python:", sys.version)
print("executable:", sys.executable)
# Out:
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\Mario\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\Mario\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\Mario\AppData\Local\Programs\Python\Python313\Lib\site-packages)
#
# [notice] A new release of pip is available: 26.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#   Using cached qdrant_client-1.18.0-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached h2-4.3.0-py3-none-any.whl.metadata (5.1 kB)
# ...

# %%
from datasets import load_dataset
from transformers import CLIPProcessor, CLIPModel
from qdrant_client import QdrantClient
from qdrant_client.models import Distance, VectorParams, PointStruct
import torch
import uuid
import os 
import cv2
from PIL import Image
import numpy as np

# %%
from datasets import load_dataset

# Login using e.g. `huggingface-cli login` to access this dataset
train_data = load_dataset("friedrichor/MSR-VTT", "train_9k")
test_data = load_dataset("friedrichor/MSR-VTT", "test_1k")
# Out:
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# msrvtt_train_9k.json:   0%|          | 0.00/14.2M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/9000 [00:00<?, ? examples/s]

# %%
print(train_data)
print(test_data)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['video_id', 'video', 'caption', 'source', 'category', 'url', 'start time', 'end time', 'id'],
#         num_rows: 9000
#     })
# })
# DatasetDict({
#     test: Dataset({
#         features: ['video_id', 'video', 'caption', 'source', 'category', 'url', 'start time', 'end time', 'id'],
#         num_rows: 1000
#     })
# })
